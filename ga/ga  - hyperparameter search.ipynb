# %%
import os
dir_path = os.getcwd()
dir_path
# Out:
# '/home/jovyan/NAT'

# %%
import itertools
import json
import numpy as np
import torch
from progress.bar import Bar
from ga import GA

from preprocess import load_tensors, phi


seed = 12345324
np.random.seed(seed)
torch.random.manual_seed(seed)

### PSO Hyperparameters
pso_epochs = 2000
inertia = 0.1
a1 = 1.1
a2 = 2.9
population_size = 30
search_range = 10

### GA Hyperparameters
max_hidden_units = 10

D_N_range = [[3,30],[4,40],[5,50],[6,60]]
T_range = [10, 100, 250, 500]
p_m_range = np.logspace(-4, -1)
p_c_range = [0,0.5,0.7]


x_train, y_train, x_val, y_val, x_test, y_test = load_tensors('/home/jovyan/NAT/data/two_spirals.dat')


param_combinations = list(itertools.product(D_N_range, T_range, p_m_range, p_c_range))
bar = Bar('Hyperparameter set', max=len(param_combinations))


for params in param_combinations:
    D = params[0][0]
    N = params[0][1]
    T = params[1]
    p_m = params[2]
    p_c = params[3]
    GA_ = GA(x_train=x_train, y_train=y_train,
             x_val=x_val, y_val=y_val,
             D=D, N=N,
             T=T, p_c=p_c, p_m=p_m, seed=seed, max_hidden_units = max_hidden_units,
             inertia=inertia, a1=a1, a2=a2, population_size=population_size,
             search_range=search_range, phi=phi)

    best_network_structure, validation_loss, validation_accuracy = GA_.run(pso_epochs)

    print(f" Validation Loss={validation_loss}")
    if validation_loss < best_validation_loss:
        best_D = D
        best_N = N
        best_T = T
        best_p_m = p_m
        best_p_c = p_c
        best_validation_loss = validation_loss

    bar.next()

with open("data/hyperparamsearch/bestparamsGA.json", 'w') as fp:
    json.dump({"D": best_D, "N": best_N, "T": best_T, "p_m": best_p_m, "p_c": best_p_c, "validation_loss": best_validation_loss}, fp)
# Out:
# Currently training: [3. 2. 1.].
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-3f2bc7f039e5> in <module>
#      50              search_range=search_range, phi=phi)
#      51
# ---> 52     best_network_structure, validation_loss, validation_accuracy = GA_.run(pso_epochs)
#      53
#      54     print(f" Validation Loss={validation_loss}")
#
# ~/NAT/ga.py in run(self, num_epochs)
#     154             # Selection process
#     155             intermediate_pop = self.roulette_wheel_selection(sorted_pop, fitness_list)
# --> 156             # Update for the next generation, here is where we crossover and mutation
#     157             self.population = self.new_generation(intermediate_pop)
#     158             print(t), print(self.population)
#
# ~/NAT/ga.py in fitness_func(self, num_epochs)
#      73                                                  inertia=self.inertia, a1=self.a1,a2=self.a2,
#      74                                                  population_size=self.population_size, search_space=self.search_range,
# ---> 75                                                  seed=self.seed, epochs=num_epochs)
#      76
#      77             fitness = training_instance.get_current_performances().loc[('val', "fitness")]
#
# ~/NAT/training.py in __init__(self, x_train, y_train, network_structure, inertia, a1, a2, population_size, search_space, epochs, seed, nonlinearity_keys, x_val, y_val, cache_loc, device, verbose)
#      56                                               )
#      57             self.progress_bar = Bar('PSO epoch', max=self.epochs)
# ---> 58             self._fit()
#      59
#      60     def _fit(self):
#
# ~/NAT/training.py in _fit(self)
#      75                 self.performances.loc[("val", "accuracy")][i] = val_acc
#      76
# ---> 77             self.optimizer.step()
#      78
#      79             if self.verbose:
#
# ~/NAT/optimization.py in step(self, closure)
#      58                     particle_fitness = self.loss(particle_predictions, self.labels.type(torch.FloatTensor).cuda())
#      59                 else:
# ---> 60                     particle_predictions = self.model(self.features)
#      61                     particle_fitness = self.loss(particle_predictions, self.labels.type(torch.FloatTensor))
#      62
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/NAT/models.py in forward(self, x)
#      47
#      48     def forward(self, x):
# ---> 49         for i, layer in enumerate(self.layers[:-1]):
#      50             x = self.nonlinearities[i](layer(x))
#      51         x = self.layers[-1](x)
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/container.py in __getitem__(self, idx)
#     160     def __getitem__(self, idx: int) -> Module:
#     161         if isinstance(idx, slice):
# --> 162             return self.__class__(list(self._modules.values())[idx])
#     163         else:
#     164             return self._modules[self._get_abs_string_index(idx)]
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/container.py in __init__(self, modules)
#     146         super(ModuleList, self).__init__()
#     147         if modules is not None:
# --> 148             self += modules
#     149
#     150     def _get_abs_string_index(self, idx):
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/container.py in __iadd__(self, modules)
#     187
#     188     def __iadd__(self: T, modules: Iterable[Module]) -> T:
# --> 189         return self.extend(modules)
#     190
#     191     @_copy_to_script_wrapper
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/container.py in extend(self, modules)
#     226         offset = len(self)
#     227         for i, module in enumerate(modules):
# --> 228             self.add_module(str(offset + i), module)
#     229         return self
#     230
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in add_module(self, name, module)
#     347             raise TypeError("module name should be a string. Got {}".format(
#     348                 torch.typename(name)))
# --> 349         elif hasattr(self, name) and name not in self._modules:
#     350             raise KeyError("attribute '{}' already exists".format(name))
#     351         elif '.' in name:
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     777                 return modules[name]
#     778         raise ModuleAttributeError("'{}' object has no attribute '{}'".format(
# --> 779             type(self).__name__, name))
#     780
#     781     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# KeyboardInterrupt:

# %%
param_combinations = list(itertools.product(D_N_range, T_range, p_m_range, p_c_range))
len(param_combinations)
# Out:
# 2400

# %%
import itertools
import json
import numpy as np
import torch
from progress.bar import Bar
from ga import GA

from preprocess import load_tensors, phi


seed = 12345324
np.random.seed(seed)
torch.random.manual_seed(seed)

### PSO Hyperparameters
pso_epochs = 2000
inertia = 0.1
a1 = 1.1
a2 = 2.9
population_size = 30
search_range = 10


D = 3
N = 10
T = 1
p_m = 0.03
p_c = 0.7

x_train, y_train, x_val, y_val, x_test, y_test = load_tensors('/home/jovyan/NAT/data/two_spirals.dat')

GA_ = GA(x_train=x_train, y_train=y_train,
         x_val=x_val, y_val=y_val,
         D=D, N=N,
         T=T, p_c=p_c, p_m=p_m, seed=seed, max_hidden_units = 2,
         inertia=inertia, a1=a1, a2=a2, population_size=population_size,
         search_range=search_range, phi=phi)
a, b, c = GA_.run(10)
# Out:
# Currently training: [3. 1. 1.].
# Loaded from disk.
# [3. 1. 1.] with fitness 9    tensor(0.6591, requires_grad=True)
# Name: (val, fitness), dtype: object.
# 9    [tensor(0.5750)]
# Name: (val, accuracy), dtype: object
# Currently training: [5. 1. 1.].
# Loaded from disk.
# [5. 1. 1.] with fitness 9    tensor(0.6934, requires_grad=True)
# Name: (val, fitness), dtype: object.
# 9    [tensor(0.5250)]
# Name: (val, accuracy), dtype: object
# Currently training: [4. 0. 1.].
# Loaded from disk.
# [4. 0. 1.] with fitness 9    tensor(1.7697, requires_grad=True)
# Name: (val, fitness), dtype: object.
# 9    [tensor(0.5500)]
# Name: (val, accuracy), dtype: object
# Currently training: [2. 0. 1.].
# Loaded from disk.
# [2. 0. 1.] with fitness 9    tensor(0.7520, requires_grad=True)
# Name: (val, fitness), dtype: object.
# 9    [tensor(0.5500)]
# Name: (val, accuracy), dtype: object
# Currently training: [3. 1. 1.].
# Loaded from disk.
# [3. 1. 1.] with fitness 9    tensor(0.6591, requires_grad=True)
# Name: (val, fitness), dtype: object.
# 9    [tensor(0.5750)]
# Name: (val, accuracy), dtype: object
# Currently training: [3. 1. 1.].
# Loaded from disk.
# [3. 1. 1.] with fitness 9    tensor(0.6591, requires_grad=True)
# Name: (val, fitness), dtype: object.
# 9    [tensor(0.5750)]
# Name: (val, accuracy), dtype: object
# Currently training: [4. 1. 1.].
# Loaded from disk.
# [4. 1. 1.] with fitness 9    tensor(0.7335, requires_grad=True)
# Name: (val, fitness), dtype: object.
# 9    [tensor(0.5250)]
# Name: (val, accuracy), dtype: object
# Currently training: [1. 0. 1.].
# Loaded from disk.
# [1. 0. 1.] with fitness 9    tensor(0.6932, requires_grad=True)
# Name: (val, fitness), dtype: object.
# 9    [tensor(0.5250)]
# Name: (val, accuracy), dtype: object
# Currently training: [3. 0. 1.].
# Loaded from disk.
# [3. 0. 1.] with fitness 9    tensor(2.0896, requires_grad=True)
# Name: (val, fitness), dtype: object.
# 9    [tensor(0.3625)]
# Name: (val, accuracy), dtype: object
# Currently training: [2. 1. 1.].
# Loaded from disk.
# [2. 1. 1.] with fitness 9    tensor(0.7042, requires_grad=True)
# Name: (val, fitness), dtype: object.
# 9    [tensor(0.5250)]
# Name: (val, accuracy), dtype: object
# [0.12048351 0.12048351 0.12048351 0.11455216 0.1145198  0.11275666
#  0.10825732 0.10559099 0.0448711  0.03800143]
# 0
# [[2. 1. 1.]
#  [2. 1. 1.]
#  [2. 1. 1.]
#  [3. 1. 1.]
#  [4. 1. 1.]
#  [3. 0. 1.]
#  [2. 1. 1.]
#  [3. 0. 1.]
#  [3. 1. 1.]
#  [3. 1. 1.]]
# Currently training: [2. 1. 1.].
# Loaded from disk.
# [2. 1. 1.] with fitness 9    tensor(0.7042, requires_grad=True)
# Name: (val, fitness), dtype: object.
# 9    [tensor(0.5250)]
# Name: (val, accuracy), dtype: object
# Currently training: [2. 1. 1.].
# Loaded from disk.
# [2. 1. 1.] with fitness 9    tensor(0.7042, requires_grad=True)
# Name: (val, fitness), dtype: object.
# 9    [tensor(0.5250)]
# Name: (val, accuracy), dtype: object
# Currently training: [2. 1. 1.].
# Loaded from disk.
# [2. 1. 1.] with fitness 9    tensor(0.7042, requires_grad=True)
# Name: (val, fitness), dtype: object.
# 9    [tensor(0.5250)]
# Name: (val, accuracy), dtype: object
# Currently training: [3. 1. 1.].
# Loaded from disk.
# [3. 1. 1.] with fitness 9    tensor(0.6591, requires_grad=True)
# Name: (val, fitness), dtype: object.
# 9    [tensor(0.5750)]
# Name: (val, accuracy), dtype: object
# Currently training: [4. 1. 1.].
# Loaded from disk.
# [4. 1. 1.] with fitness 9    tensor(0.7335, requires_grad=True)
# Name: (val, fitness), dtype: object.
# 9    [tensor(0.5250)]
# Name: (val, accuracy), dtype: object
# Currently training: [3. 0. 1.].
# Loaded from disk.
# [3. 0. 1.] with fitness 9    tensor(2.0896, requires_grad=True)
# Name: (val, fitness), dtype: object.
# 9    [tensor(0.3625)]
# Name: (val, accuracy), dtype: object
# Currently training: [2. 1. 1.].
# Loaded from disk.
# [2. 1. 1.] with fitness 9    tensor(0.7042, requires_grad=True)
# Name: (val, fitness), dtype: object.
# 9    [tensor(0.5250)]
# Name: (val, accuracy), dtype: object
# Currently training: [3. 0. 1.].
# Loaded from disk.
# [3. 0. 1.] with fitness 9    tensor(2.0896, requires_grad=True)
# Name: (val, fitness), dtype: object.
# 9    [tensor(0.3625)]
# Name: (val, accuracy), dtype: object
# Currently training: [3. 1. 1.].
# Loaded from disk.
# [3. 1. 1.] with fitness 9    tensor(0.6591, requires_grad=True)
# Name: (val, fitness), dtype: object.
# 9    [tensor(0.5750)]
# Name: (val, accuracy), dtype: object
# Currently training: [3. 1. 1.].
# Loaded from disk.
# [3. 1. 1.] with fitness 9    tensor(0.6591, requires_grad=True)
# Name: (val, fitness), dtype: object.
# 9    [tensor(0.5750)]
# Name: (val, accuracy), dtype: object
