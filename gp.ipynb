# %%
import numpy as np
import torch
from torch import nn
from gp import GP

from models import BaselineSpiralClassifier
from optimization import PSO
from preprocess import load_tensors, phi

from training import TrainingInstance

seed = 12345324
np.random.seed(seed)
torch.random.manual_seed(seed)

### PSO Hyperparameters
epochs = 1
inertia = 0.7
a1 = 1.4
a2 = 1.8
population_size = 30
search_range = 1

### GA Hyperparameters
D = 8
N = 30
T = 1
p_c=0.7
p_m = 0.01
max_hidden_units = 10

x_train, y_train, x_val, y_val, x_test, y_test = load_tensors('/home/mclancy/Documents/notes/edinburgh/year4/naturalcomputing/coursework/data/two_spirals.dat')

GP_ = GP(x_train=x_train, y_train=y_train,
         x_val=x_val, y_val=y_val,
         D=D, N=N,
         T=T, p_c=p_c, p_m=p_m, seed=seed, max_hidden_units = max_hidden_units,
         inertia=inertia, a1=a1, a2=a2, population_size=population_size,
         search_range=search_range, phi=phi)

bestthig, a = GP_.run(2)
print(bestthig)
print(a)
# Out:
# Currently training: [array([0, 1, 0, 0, 0, 1]) list([9, 'A']) list([7, 'A']) list([5, 'A'])
#  list([5, 'C']) list([0, 'B']) list([6, 'A']) 1].
# [array([0, 1, 0, 0, 0, 1]) list([9, 'A']) list([7, 'A']) list([5, 'A'])
#  list([5, 'C']) list([0, 'B']) list([6, 'A']) 1] with fitness 1    tensor(0.6991, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 0, 1, 1, 1]) list([3, 'C']) list([2, 'C']) list([5, 'C'])
#  list([7, 'B']) list([1, 'A']) list([1, 'A']) 1].
# [array([1, 0, 0, 1, 1, 1]) list([3, 'C']) list([2, 'C']) list([5, 'C'])
#  list([7, 'B']) list([1, 'A']) list([1, 'A']) 1] with fitness 1    tensor(0.6934, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 0, 0, 0, 1]) list([0, 'B']) list([9, 'A']) list([7, 'B'])
#  list([2, 'B']) list([7, 'A']) list([1, 'A']) 1].
# [array([1, 0, 0, 0, 0, 1]) list([0, 'B']) list([9, 'A']) list([7, 'B'])
#  list([2, 'B']) list([7, 'A']) list([1, 'A']) 1] with fitness 1    tensor(0.6943, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 1, 1, 1, 1, 0]) list([0, 'B']) list([7, 'C']) list([1, 'A'])
#  list([8, 'C']) list([1, 'B']) list([8, 'A']) 1].
# [array([0, 1, 1, 1, 1, 0]) list([0, 'B']) list([7, 'C']) list([1, 'A'])
#  list([8, 'C']) list([1, 'B']) list([8, 'A']) 1] with fitness 1    tensor(0.8120, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 0, 0, 0, 1]) list([6, 'A']) list([9, 'C']) list([7, 'C'])
#  list([4, 'B']) list([5, 'C']) list([4, 'B']) 1].
# [array([1, 0, 0, 0, 0, 1]) list([6, 'A']) list([9, 'C']) list([7, 'C'])
#  list([4, 'B']) list([5, 'C']) list([4, 'B']) 1] with fitness 1    tensor(0.6960, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 1, 1, 1, 1, 1]) list([4, 'B']) list([9, 'C']) list([6, 'B'])
#  list([6, 'C']) list([5, 'C']) list([6, 'A']) 1].
# [array([0, 1, 1, 1, 1, 1]) list([4, 'B']) list([9, 'C']) list([6, 'B'])
#  list([6, 'C']) list([5, 'C']) list([6, 'A']) 1] with fitness 1    tensor(0.6953, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 0, 1, 0, 0, 0]) list([1, 'B']) list([6, 'B']) list([7, 'B'])
#  list([5, 'B']) list([9, 'C']) list([9, 'B']) 1].
# [array([0, 0, 1, 0, 0, 0]) list([1, 'B']) list([6, 'B']) list([7, 'B'])
#  list([5, 'B']) list([9, 'C']) list([9, 'B']) 1] with fitness 1    tensor(0.7233, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 0, 0, 0, 1, 1]) list([7, 'B']) list([5, 'A']) list([7, 'B'])
#  list([6, 'B']) list([3, 'A']) list([4, 'A']) 1].
# [array([0, 0, 0, 0, 1, 1]) list([7, 'B']) list([5, 'A']) list([7, 'B'])
#  list([6, 'B']) list([3, 'A']) list([4, 'A']) 1] with fitness 1    tensor(0.6961, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 1, 0, 0, 1, 0]) list([5, 'C']) list([2, 'B']) list([4, 'A'])
#  list([2, 'C']) list([5, 'B']) list([0, 'C']) 1].
# [array([1, 1, 0, 0, 1, 0]) list([5, 'C']) list([2, 'B']) list([4, 'A'])
#  list([2, 'C']) list([5, 'B']) list([0, 'C']) 1] with fitness 1    tensor(0.6951, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 1, 0, 0, 0, 1]) list([6, 'C']) list([7, 'A']) list([6, 'A'])
#  list([5, 'A']) list([0, 'C']) list([8, 'C']) 1].
# [array([1, 1, 0, 0, 0, 1]) list([6, 'C']) list([7, 'A']) list([6, 'A'])
#  list([5, 'A']) list([0, 'C']) list([8, 'C']) 1] with fitness 1    tensor(0.7021, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 1, 1, 0, 0, 1]) list([0, 'A']) list([0, 'B']) list([8, 'B'])
#  list([6, 'A']) list([3, 'B']) list([3, 'B']) 1].
# [array([0, 1, 1, 0, 0, 1]) list([0, 'A']) list([0, 'B']) list([8, 'B'])
#  list([6, 'A']) list([3, 'B']) list([3, 'B']) 1] with fitness 1    tensor(0.7018, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 0, 1, 1, 0]) list([3, 'B']) list([3, 'C']) list([2, 'A'])
#  list([5, 'B']) list([0, 'B']) list([2, 'A']) 1].
# [array([1, 0, 0, 1, 1, 0]) list([3, 'B']) list([3, 'C']) list([2, 'A'])
#  list([5, 'B']) list([0, 'B']) list([2, 'A']) 1] with fitness 1    tensor(0.6963, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 1, 0, 0, 1, 1]) list([0, 'A']) list([5, 'C']) list([4, 'B'])
#  list([3, 'B']) list([9, 'C']) list([4, 'A']) 1].
# [array([1, 1, 0, 0, 1, 1]) list([0, 'A']) list([5, 'C']) list([4, 'B'])
#  list([3, 'B']) list([9, 'C']) list([4, 'A']) 1] with fitness 1    tensor(0.6961, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 1, 0, 1, 1, 1]) list([4, 'B']) list([3, 'B']) list([3, 'B'])
#  list([0, 'B']) list([6, 'B']) list([8, 'B']) 1].
# [array([1, 1, 0, 1, 1, 1]) list([4, 'B']) list([3, 'B']) list([3, 'B'])
#  list([0, 'B']) list([6, 'B']) list([8, 'B']) 1] with fitness 1    tensor(0.7076, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 1, 1, 1, 1, 0]) list([7, 'B']) list([6, 'B']) list([6, 'B'])
#  list([6, 'B']) list([6, 'C']) list([2, 'B']) 1].
# [array([0, 1, 1, 1, 1, 0]) list([7, 'B']) list([6, 'B']) list([6, 'B'])
#  list([6, 'B']) list([6, 'C']) list([2, 'B']) 1] with fitness 1    tensor(0.6925, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 1, 1, 0, 1, 1]) list([7, 'B']) list([5, 'A']) list([2, 'B'])
#  list([7, 'A']) list([9, 'B']) list([0, 'C']) 1].
# [array([1, 1, 1, 0, 1, 1]) list([7, 'B']) list([5, 'A']) list([2, 'B'])
#  list([7, 'A']) list([9, 'B']) list([0, 'C']) 1] with fitness 1    tensor(0.6972, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 1, 1, 0, 0, 0]) list([4, 'B']) list([2, 'A']) list([3, 'B'])
#  list([8, 'A']) list([2, 'C']) list([2, 'A']) 1].
# [array([0, 1, 1, 0, 0, 0]) list([4, 'B']) list([2, 'A']) list([3, 'B'])
#  list([8, 'A']) list([2, 'C']) list([2, 'A']) 1] with fitness 1    tensor(0.6956, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 1, 1, 0, 1, 1]) list([9, 'C']) list([2, 'C']) list([3, 'A'])
#  list([5, 'A']) list([0, 'C']) list([0, 'A']) 1].
# [array([1, 1, 1, 0, 1, 1]) list([9, 'C']) list([2, 'C']) list([3, 'A'])
#  list([5, 'A']) list([0, 'C']) list([0, 'A']) 1] with fitness 1    tensor(0.6962, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 0, 0, 0, 1]) list([7, 'A']) list([9, 'B']) list([5, 'B'])
#  list([6, 'C']) list([1, 'C']) list([0, 'C']) 1].
# [array([1, 0, 0, 0, 0, 1]) list([7, 'A']) list([9, 'B']) list([5, 'B'])
#  list([6, 'C']) list([1, 'C']) list([0, 'C']) 1] with fitness 1    tensor(0.6930, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 1, 1, 1, 0]) list([1, 'C']) list([3, 'B']) list([6, 'A'])
#  list([3, 'C']) list([8, 'C']) list([1, 'B']) 1].
# [array([1, 0, 1, 1, 1, 0]) list([1, 'C']) list([3, 'B']) list([6, 'A'])
#  list([3, 'C']) list([8, 'C']) list([1, 'B']) 1] with fitness 1    tensor(0.6939, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 0, 0, 1, 1]) list([4, 'B']) list([5, 'B']) list([6, 'C'])
#  list([8, 'A']) list([5, 'C']) list([7, 'B']) 1].
# [array([1, 0, 0, 0, 1, 1]) list([4, 'B']) list([5, 'B']) list([6, 'C'])
#  list([8, 'A']) list([5, 'C']) list([7, 'B']) 1] with fitness 1    tensor(0.7046, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 1, 1, 0, 0, 0]) list([3, 'C']) list([6, 'B']) list([4, 'B'])
#  list([2, 'B']) list([1, 'C']) list([3, 'B']) 1].
# [array([0, 1, 1, 0, 0, 0]) list([3, 'C']) list([6, 'B']) list([4, 'B'])
#  list([2, 'B']) list([1, 'C']) list([3, 'B']) 1] with fitness 1    tensor(0.6926, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 1, 1, 0, 1, 0]) list([4, 'A']) list([2, 'C']) list([2, 'B'])
#  list([8, 'A']) list([6, 'B']) list([6, 'A']) 1].
# [array([0, 1, 1, 0, 1, 0]) list([4, 'A']) list([2, 'C']) list([2, 'B'])
#  list([8, 'A']) list([6, 'B']) list([6, 'A']) 1] with fitness 1    tensor(0.6919, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 1, 1, 0, 0]) list([1, 'A']) list([3, 'C']) list([8, 'B'])
#  list([5, 'B']) list([5, 'A']) list([3, 'B']) 1].
# [array([1, 0, 1, 1, 0, 0]) list([1, 'A']) list([3, 'C']) list([8, 'B'])
#  list([5, 'B']) list([5, 'A']) list([3, 'B']) 1] with fitness 1    tensor(0.6934, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 0, 0, 1, 1, 1]) list([8, 'B']) list([4, 'A']) list([9, 'B'])
#  list([8, 'B']) list([0, 'C']) list([6, 'A']) 1].
# [array([0, 0, 0, 1, 1, 1]) list([8, 'B']) list([4, 'A']) list([9, 'B'])
#  list([8, 'B']) list([0, 'C']) list([6, 'A']) 1] with fitness 1    tensor(0.7007, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 0, 1, 0, 1, 1]) list([0, 'C']) list([8, 'B']) list([7, 'C'])
#  list([7, 'A']) list([2, 'C']) list([8, 'C']) 1].
# [array([0, 0, 1, 0, 1, 1]) list([0, 'C']) list([8, 'B']) list([7, 'C'])
#  list([7, 'A']) list([2, 'C']) list([8, 'C']) 1] with fitness 1    tensor(0.6918, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 0, 1, 0, 1]) list([0, 'C']) list([2, 'C']) list([9, 'A'])
#  list([6, 'B']) list([7, 'C']) list([6, 'A']) 1].
# [array([1, 0, 0, 1, 0, 1]) list([0, 'C']) list([2, 'C']) list([9, 'A'])
#  list([6, 'B']) list([7, 'C']) list([6, 'A']) 1] with fitness 1    tensor(0.6936, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 1, 0, 1, 1, 0]) list([3, 'A']) list([5, 'C']) list([0, 'B'])
#  list([7, 'C']) list([1, 'B']) list([2, 'A']) 1].
# [array([0, 1, 0, 1, 1, 0]) list([3, 'A']) list([5, 'C']) list([0, 'B'])
#  list([7, 'C']) list([1, 'B']) list([2, 'A']) 1] with fitness 1    tensor(0.6947, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 1, 1, 1, 0]) list([7, 'B']) list([5, 'B']) list([2, 'C'])
#  list([2, 'B']) list([8, 'B']) list([8, 'C']) 1].
# [array([1, 0, 1, 1, 1, 0]) list([7, 'B']) list([5, 'B']) list([2, 'C'])
#  list([2, 'B']) list([8, 'B']) list([8, 'C']) 1] with fitness 1    tensor(0.6927, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 0, 1, 0, 0, 0]) list([6, 'B']) list([7, 'C']) list([6, 'A'])
#  list([5, 'C']) list([8, 'C']) list([6, 'B']) 1].
# [array([0, 0, 1, 0, 0, 0]) list([6, 'B']) list([7, 'C']) list([6, 'A'])
#  list([5, 'C']) list([8, 'C']) list([6, 'B']) 1] with fitness 1    tensor(0.6927, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# 0
# [[array([1, 0, 0, 1, 0, 1]) list([4, 'B']) list([3, 'B']) list([3, 'B'])
#   list([0, 'B']) list([6, 'B']) list([8, 'B']) 1]
#  [array([1, 0, 0, 0, 0, 1]) list([7, 'A']) list([9, 'B']) list([5, 'B'])
#   list([6, 'C']) list([1, 'C']) list([0, 'C']) 1]
#  [array([1, 0, 1, 1, 1, 0]) list([7, 'B']) list([5, 'B']) list([2, 'C'])
#   list([2, 'B']) list([5, 'B']) list([0, 'C']) 1]
#  [array([1, 1, 0, 0, 1, 1]) list([0, 'A']) list([5, 'C']) list([4, 'B'])
#   list([0, 'B']) list([6, 'B']) list([8, 'B']) 1]
#  [array([1, 0, 0, 0, 0, 1]) list([4, 'B']) list([9, 'C']) list([6, 'B'])
#   list([6, 'C']) list([5, 'C']) list([6, 'A']) 1]
#  [array([0, 1, 1, 0, 0, 0]) list([1, 'A']) list([3, 'C']) list([8, 'B'])
#   list([1, 'C']) list([5, 'A']) list([3, 'B']) 1]
#  [array([1, 1, 1, 0, 1, 1]) list([9, 'C']) list([9, 'A']) list([7, 'B'])
#   list([2, 'B']) list([7, 'A']) list([1, 'A']) 1]
#  [array([1, 0, 1, 1, 1, 0]) list([1, 'C']) list([3, 'B']) list([6, 'A'])
#   list([3, 'C']) list([8, 'C']) list([3, 'B']) 1]
#  [array([1, 0, 1, 1, 1, 0]) list([0, 'C']) list([2, 'C']) list([9, 'A'])
#   list([6, 'B']) list([7, 'C']) list([6, 'A']) 1]
#  [array([0, 1, 1, 0, 0, 1]) list([0, 'A']) list([8, 'B']) list([7, 'C'])
#   list([7, 'A']) list([2, 'C']) list([8, 'C']) 1]
#  [array([1, 0, 0, 1, 1, 1]) list([3, 'C']) list([2, 'C']) list([5, 'C'])
#   list([6, 'B']) list([6, 'C']) list([2, 'B']) 1]
#  [array([0, 1, 1, 1, 1, 0]) list([0, 'B']) list([2, 'A']) list([3, 'B'])
#   list([8, 'A']) list([2, 'C']) list([2, 'A']) 1]
#  [array([0, 1, 1, 1, 1, 1]) list([4, 'B']) list([9, 'C']) list([6, 'B'])
#   list([6, 'C']) list([0, 'B']) list([2, 'A']) 1]
#  [array([0, 1, 1, 1, 1, 0]) list([7, 'B']) list([6, 'B']) list([5, 'A'])
#   list([5, 'C']) list([0, 'B']) list([6, 'A']) 1]
#  [array([0, 1, 0, 1, 1, 0]) list([3, 'A']) list([5, 'C']) list([6, 'B'])
#   list([6, 'C']) list([5, 'C']) list([6, 'A']) 1]
#  [array([0, 1, 1, 1, 1, 1]) list([4, 'B']) list([9, 'C']) list([0, 'B'])
#   list([7, 'C']) list([1, 'B']) list([2, 'A']) 1]
#  [array([0, 1, 0, 0, 0, 1]) list([9, 'A']) list([7, 'A']) list([6, 'B'])
#   list([6, 'B']) list([6, 'C']) list([2, 'B']) 1]
#  [array([1, 0, 0, 1, 1, 0]) list([3, 'B']) list([3, 'C']) list([2, 'A'])
#   list([5, 'B']) list([5, 'C']) list([6, 'A']) 1]
#  [array([0, 1, 1, 0, 0, 0]) list([4, 'B']) list([7, 'C']) list([1, 'A'])
#   list([8, 'C']) list([1, 'B']) list([8, 'A']) 1]
#  [array([0, 1, 1, 1, 1, 0]) list([7, 'B']) list([6, 'B']) list([6, 'B'])
#   list([7, 'B']) list([1, 'A']) list([1, 'A']) 1]
#  [array([0, 0, 1, 0, 1, 1]) list([0, 'C']) list([0, 'B']) list([8, 'B'])
#   list([6, 'A']) list([3, 'B']) list([3, 'B']) 1]
#  [array([1, 0, 0, 1, 0, 1]) list([7, 'B']) list([5, 'B']) list([2, 'C'])
#   list([2, 'B']) list([8, 'B']) list([8, 'C']) 1]
#  [array([1, 0, 1, 1, 0, 0]) list([1, 'A']) list([3, 'C']) list([8, 'B'])
#   list([1, 'C']) list([5, 'A']) list([1, 'B']) 1]
#  [array([1, 0, 0, 0, 0, 1]) list([0, 'B']) list([2, 'C']) list([3, 'A'])
#   list([5, 'A']) list([0, 'C']) list([0, 'A']) 1]
#  [array([1, 0, 1, 1, 0, 0]) list([3, 'C']) list([6, 'B']) list([4, 'B'])
#   list([2, 'B']) list([1, 'C']) list([3, 'B']) 1]
#  [array([0, 1, 1, 1, 1, 1]) list([6, 'A']) list([9, 'C']) list([7, 'C'])
#   list([4, 'B']) list([5, 'C']) list([4, 'B']) 1]
#  [array([1, 1, 0, 1, 1, 1]) list([4, 'B']) list([3, 'B']) list([3, 'B'])
#   list([3, 'B']) list([9, 'C']) list([4, 'A']) 1]
#  [list([1, 1, 0, 0, 1, 0]) list([5, 'C']) list([2, 'B']) list([4, 'A'])
#   list([2, 'C']) list([8, 'B']) list([8, 'C']) 1]
#  [array([0, 1, 0, 0, 0, 1]) list([9, 'A']) list([7, 'A']) list([5, 'A'])
#   list([5, 'C']) list([0, 'B']) list([6, 'A']) 1]
#  [array([1, 1, 0, 1, 1, 1]) list([0, 'C']) list([2, 'C']) list([9, 'A'])
#   list([6, 'B']) list([7, 'C']) list([6, 'A']) 1]]
# Currently training: [array([1, 0, 0, 1, 0, 1]) list([4, 'B']) list([3, 'B']) list([3, 'B'])
#  list([0, 'B']) list([6, 'B']) list([8, 'B']) 1].
# [array([1, 0, 0, 1, 0, 1]) list([4, 'B']) list([3, 'B']) list([3, 'B'])
#  list([0, 'B']) list([6, 'B']) list([8, 'B']) 1] with fitness 1    tensor(0.7108, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 0, 0, 0, 1]) list([7, 'A']) list([9, 'B']) list([5, 'B'])
#  list([6, 'C']) list([1, 'C']) list([0, 'C']) 1].
# Loaded from disk.
# [array([1, 0, 0, 0, 0, 1]) list([7, 'A']) list([9, 'B']) list([5, 'B'])
#  list([6, 'C']) list([1, 'C']) list([0, 'C']) 1] with fitness 1    tensor(0.6930, requires_grad=True)
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 1, 1, 1, 0]) list([7, 'B']) list([5, 'B']) list([2, 'C'])
#  list([2, 'B']) list([5, 'B']) list([0, 'C']) 1].
# [array([1, 0, 1, 1, 1, 0]) list([7, 'B']) list([5, 'B']) list([2, 'C'])
#  list([2, 'B']) list([5, 'B']) list([0, 'C']) 1] with fitness 1    tensor(0.6898, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 1, 0, 0, 1, 1]) list([0, 'A']) list([5, 'C']) list([4, 'B'])
#  list([0, 'B']) list([6, 'B']) list([8, 'B']) 1].
# [array([1, 1, 0, 0, 1, 1]) list([0, 'A']) list([5, 'C']) list([4, 'B'])
#  list([0, 'B']) list([6, 'B']) list([8, 'B']) 1] with fitness 1    tensor(0.7005, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 0, 0, 0, 1]) list([4, 'B']) list([9, 'C']) list([6, 'B'])
#  list([6, 'C']) list([5, 'C']) list([6, 'A']) 1].
# [array([1, 0, 0, 0, 0, 1]) list([4, 'B']) list([9, 'C']) list([6, 'B'])
#  list([6, 'C']) list([5, 'C']) list([6, 'A']) 1] with fitness 1    tensor(0.6913, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 1, 1, 0, 0, 0]) list([1, 'A']) list([3, 'C']) list([8, 'B'])
#  list([1, 'C']) list([5, 'A']) list([3, 'B']) 1].
# [array([0, 1, 1, 0, 0, 0]) list([1, 'A']) list([3, 'C']) list([8, 'B'])
#  list([1, 'C']) list([5, 'A']) list([3, 'B']) 1] with fitness 1    tensor(0.6946, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 1, 1, 0, 1, 1]) list([9, 'C']) list([9, 'A']) list([7, 'B'])
#  list([2, 'B']) list([7, 'A']) list([1, 'A']) 1].
# [array([1, 1, 1, 0, 1, 1]) list([9, 'C']) list([9, 'A']) list([7, 'B'])
#  list([2, 'B']) list([7, 'A']) list([1, 'A']) 1] with fitness 1    tensor(0.6959, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 1, 1, 1, 0]) list([1, 'C']) list([3, 'B']) list([6, 'A'])
#  list([3, 'C']) list([8, 'C']) list([3, 'B']) 1].
# [array([1, 0, 1, 1, 1, 0]) list([1, 'C']) list([3, 'B']) list([6, 'A'])
#  list([3, 'C']) list([8, 'C']) list([3, 'B']) 1] with fitness 1    tensor(0.6982, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 1, 1, 1, 0]) list([0, 'C']) list([2, 'C']) list([9, 'A'])
#  list([6, 'B']) list([7, 'C']) list([6, 'A']) 1].
# [array([1, 0, 1, 1, 1, 0]) list([0, 'C']) list([2, 'C']) list([9, 'A'])
#  list([6, 'B']) list([7, 'C']) list([6, 'A']) 1] with fitness 1    tensor(0.7243, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 1, 1, 0, 0, 1]) list([0, 'A']) list([8, 'B']) list([7, 'C'])
#  list([7, 'A']) list([2, 'C']) list([8, 'C']) 1].
# Loaded from disk.
# [array([0, 1, 1, 0, 0, 1]) list([0, 'A']) list([8, 'B']) list([7, 'C'])
#  list([7, 'A']) list([2, 'C']) list([8, 'C']) 1] with fitness 1    tensor(0.6918, requires_grad=True)
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 0, 1, 1, 1]) list([3, 'C']) list([2, 'C']) list([5, 'C'])
#  list([6, 'B']) list([6, 'C']) list([2, 'B']) 1].
# [array([1, 0, 0, 1, 1, 1]) list([3, 'C']) list([2, 'C']) list([5, 'C'])
#  list([6, 'B']) list([6, 'C']) list([2, 'B']) 1] with fitness 1    tensor(0.6945, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 1, 1, 1, 1, 0]) list([0, 'B']) list([2, 'A']) list([3, 'B'])
#  list([8, 'A']) list([2, 'C']) list([2, 'A']) 1].
# [array([0, 1, 1, 1, 1, 0]) list([0, 'B']) list([2, 'A']) list([3, 'B'])
#  list([8, 'A']) list([2, 'C']) list([2, 'A']) 1] with fitness 1    tensor(0.6958, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 1, 1, 1, 1, 1]) list([4, 'B']) list([9, 'C']) list([6, 'B'])
#  list([6, 'C']) list([0, 'B']) list([2, 'A']) 1].
# [array([0, 1, 1, 1, 1, 1]) list([4, 'B']) list([9, 'C']) list([6, 'B'])
#  list([6, 'C']) list([0, 'B']) list([2, 'A']) 1] with fitness 1    tensor(0.6939, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 1, 1, 1, 1, 0]) list([7, 'B']) list([6, 'B']) list([5, 'A'])
#  list([5, 'C']) list([0, 'B']) list([6, 'A']) 1].
# [array([0, 1, 1, 1, 1, 0]) list([7, 'B']) list([6, 'B']) list([5, 'A'])
#  list([5, 'C']) list([0, 'B']) list([6, 'A']) 1] with fitness 1    tensor(0.6777, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 1, 0, 1, 1, 0]) list([3, 'A']) list([5, 'C']) list([6, 'B'])
#  list([6, 'C']) list([5, 'C']) list([6, 'A']) 1].
# [array([0, 1, 0, 1, 1, 0]) list([3, 'A']) list([5, 'C']) list([6, 'B'])
#  list([6, 'C']) list([5, 'C']) list([6, 'A']) 1] with fitness 1    tensor(0.6944, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 1, 1, 1, 1, 1]) list([4, 'B']) list([9, 'C']) list([0, 'B'])
#  list([7, 'C']) list([1, 'B']) list([2, 'A']) 1].
# [array([0, 1, 1, 1, 1, 1]) list([4, 'B']) list([9, 'C']) list([0, 'B'])
#  list([7, 'C']) list([1, 'B']) list([2, 'A']) 1] with fitness 1    tensor(0.6913, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 1, 0, 0, 0, 1]) list([9, 'A']) list([7, 'A']) list([6, 'B'])
#  list([6, 'B']) list([6, 'C']) list([2, 'B']) 1].
# [array([0, 1, 0, 0, 0, 1]) list([9, 'A']) list([7, 'A']) list([6, 'B'])
#  list([6, 'B']) list([6, 'C']) list([2, 'B']) 1] with fitness 1    tensor(0.6940, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 0, 1, 1, 0]) list([3, 'B']) list([3, 'C']) list([2, 'A'])
#  list([5, 'B']) list([5, 'C']) list([6, 'A']) 1].
# [array([1, 0, 0, 1, 1, 0]) list([3, 'B']) list([3, 'C']) list([2, 'A'])
#  list([5, 'B']) list([5, 'C']) list([6, 'A']) 1] with fitness 1    tensor(0.7029, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 1, 1, 0, 0, 0]) list([4, 'B']) list([7, 'C']) list([1, 'A'])
#  list([8, 'C']) list([1, 'B']) list([8, 'A']) 1].
# [array([0, 1, 1, 0, 0, 0]) list([4, 'B']) list([7, 'C']) list([1, 'A'])
#  list([8, 'C']) list([1, 'B']) list([8, 'A']) 1] with fitness 1    tensor(0.7763, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 1, 1, 1, 1, 0]) list([7, 'B']) list([6, 'B']) list([6, 'B'])
#  list([7, 'B']) list([1, 'A']) list([1, 'A']) 1].
# [array([0, 1, 1, 1, 1, 0]) list([7, 'B']) list([6, 'B']) list([6, 'B'])
#  list([7, 'B']) list([1, 'A']) list([1, 'A']) 1] with fitness 1    tensor(0.6916, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 0, 1, 0, 1, 1]) list([0, 'C']) list([0, 'B']) list([8, 'B'])
#  list([6, 'A']) list([3, 'B']) list([3, 'B']) 1].
# Loaded from disk.
# [array([0, 0, 1, 0, 1, 1]) list([0, 'C']) list([0, 'B']) list([8, 'B'])
#  list([6, 'A']) list([3, 'B']) list([3, 'B']) 1] with fitness 1    tensor(0.7018, requires_grad=True)
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 0, 1, 0, 1]) list([7, 'B']) list([5, 'B']) list([2, 'C'])
#  list([2, 'B']) list([8, 'B']) list([8, 'C']) 1].
# [array([1, 0, 0, 1, 0, 1]) list([7, 'B']) list([5, 'B']) list([2, 'C'])
#  list([2, 'B']) list([8, 'B']) list([8, 'C']) 1] with fitness 1    tensor(0.6928, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 1, 1, 0, 0]) list([1, 'A']) list([3, 'C']) list([8, 'B'])
#  list([1, 'C']) list([5, 'A']) list([1, 'B']) 1].
# [array([1, 0, 1, 1, 0, 0]) list([1, 'A']) list([3, 'C']) list([8, 'B'])
#  list([1, 'C']) list([5, 'A']) list([1, 'B']) 1] with fitness 1    tensor(0.6922, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 0, 0, 0, 1]) list([0, 'B']) list([2, 'C']) list([3, 'A'])
#  list([5, 'A']) list([0, 'C']) list([0, 'A']) 1].
# [array([1, 0, 0, 0, 0, 1]) list([0, 'B']) list([2, 'C']) list([3, 'A'])
#  list([5, 'A']) list([0, 'C']) list([0, 'A']) 1] with fitness 1    tensor(0.6914, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 0, 1, 1, 0, 0]) list([3, 'C']) list([6, 'B']) list([4, 'B'])
#  list([2, 'B']) list([1, 'C']) list([3, 'B']) 1].
# [array([1, 0, 1, 1, 0, 0]) list([3, 'C']) list([6, 'B']) list([4, 'B'])
#  list([2, 'B']) list([1, 'C']) list([3, 'B']) 1] with fitness 1    tensor(0.6945, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 1, 1, 1, 1, 1]) list([6, 'A']) list([9, 'C']) list([7, 'C'])
#  list([4, 'B']) list([5, 'C']) list([4, 'B']) 1].
# [array([0, 1, 1, 1, 1, 1]) list([6, 'A']) list([9, 'C']) list([7, 'C'])
#  list([4, 'B']) list([5, 'C']) list([4, 'B']) 1] with fitness 1    tensor(0.6940, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 1, 0, 1, 1, 1]) list([4, 'B']) list([3, 'B']) list([3, 'B'])
#  list([3, 'B']) list([9, 'C']) list([4, 'A']) 1].
# [array([1, 1, 0, 1, 1, 1]) list([4, 'B']) list([3, 'B']) list([3, 'B'])
#  list([3, 'B']) list([9, 'C']) list([4, 'A']) 1] with fitness 1    tensor(0.7011, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [list([1, 1, 0, 0, 1, 0]) list([5, 'C']) list([2, 'B']) list([4, 'A'])
#  list([2, 'C']) list([8, 'B']) list([8, 'C']) 1].
# [list([1, 1, 0, 0, 1, 0]) list([5, 'C']) list([2, 'B']) list([4, 'A'])
#  list([2, 'C']) list([8, 'B']) list([8, 'C']) 1] with fitness 1    tensor(0.6943, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# Currently training: [array([0, 1, 0, 0, 0, 1]) list([9, 'A']) list([7, 'A']) list([5, 'A'])
#  list([5, 'C']) list([0, 'B']) list([6, 'A']) 1].
# Loaded from disk.
# [array([0, 1, 0, 0, 0, 1]) list([9, 'A']) list([7, 'A']) list([5, 'A'])
#  list([5, 'C']) list([0, 'B']) list([6, 'A']) 1] with fitness 1    tensor(0.6991, requires_grad=True)
# Name: (val, fitness), dtype: object.
# Currently training: [array([1, 1, 0, 1, 1, 1]) list([0, 'C']) list([2, 'C']) list([9, 'A'])
#  list([6, 'B']) list([7, 'C']) list([6, 'A']) 1].
# [array([1, 1, 0, 1, 1, 1]) list([0, 'C']) list([2, 'C']) list([9, 'A'])
#  list([6, 'B']) list([7, 'C']) list([6, 'A']) 1] with fitness 1    tensor(0.6973, grad_fn=<BinaryCrossEntropyWith...
# Name: (val, fitness), dtype: object.
# [array([0, 1, 1, 0, 0, 0]) list([4, 'B']) list([7, 'C']) list([1, 'A'])
#  list([8, 'C']) list([1, 'B']) list([8, 'A']) 1]
# 0.7763197080035278
# /home/mclancy/.local/share/pyenv/versions/natcomp/lib/python3.8/site-packages/pandas/core/generic.py:2434: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Int64Index([0, 1], dtype='int64')]
#
#   pytables.to_hdf(
